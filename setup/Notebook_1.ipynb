# %%
# %sql

--creating a catalog 
CREATE CATALOG IF NOT EXISTS `E-Commerce`;

# %%
# %sql

--setting the catalog as default
USE CATALOG `E-Commerce`;

# %%
# %sql

--creating schema as per the medallion architecture
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

# %%
# %sql 

--check schema's in catalog 
SHOW DATABASES FROM `E-Commerce`;

# %%
# %sql
-- I created a bucket in s3 and dumped all the raw data files and then injested it into the volumes in databricks
